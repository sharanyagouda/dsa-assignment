# %%
mystr=input("enter string")
while mystr!=" ":
    length=len(mystr)
    ch=mystr[0]
    mystr=mystr.replace(ch,"")
    length1=len(mystr)
    if length1==length-1:
        print("first non repeating character=",ch)
        break
    else:
        print("no unique character found")

# %%
https://pandas.pydata.org/pandas-docs/stable/?v=20220911210828expr=input("enter  expression")
def areBracketsBalanced(expr):
    stack = []
 

    for char in expr:
        if char in ["(", "{", "["]:
 
    
            stack.append(char)
        else:
 
        
            if not stack:
                return False
            current_char = stack.pop()
            if current_char == '(':
                if char != ")":
                    return False
            if current_char == '{':
                if char != "}":
                    return False
            if current_char == '[':
                if char != "]":
                    return False
 
    
    if stack:
        return False
    return True

    
if areBracketsBalanced(expr):
    print("Balanced")
else:
    print("Not Balanced")
        
areBracketsBalanced(expr)

# %%
array=[]
num=int(input("enter number of values"))
sum=int(input("enter sum to calculate"))
for ele in range(num):
    val=int(input("enter the element"))
    array.append(val)
print(array)    

def check_sum(array,num,sum):
    for i in range(0,num):
        for j in range(i+1,num):
            if (array[i]+array[j]==sum):
                print(array[i],array[j])

check_sum(array,num,sum)

# %%
array=[]
num=int(input("enter number of values"))
for ele in range(num):
    val=int(input("enter the element"))
    array.append(val)
print("ORIGINAL ARRAY",array)
print("REVERSED ARRAY",array[::-1])

# %%
str1=input("enter 1st string")
str2=input("enter 2nd string")
temp=" "
def string_rotation(str1,str2):
    s1=len(str1)
    s2=len(str2)
    if s1!=s2:
        return 0
    temp=str1+str1
    if (temp.count(str2)>0):
        return 1    
    else:
        return 0  
if string_rotation(str1,str2):
    print("strings are rotations of each other")
else:
    print("strings are not rotations of each other")    
        
        
string_rotation(str1,str2)

# %%
postfix=input("enter postfix expression")
def isOperator(c):
    if c == "*" or c == "+" or c=="-" or c=="/" or c=="(" or c==")" or c=="^":
        return c
    else:
        pass
    
def postfix_to_prefix(postfix):
    stack=[]
    length=len(postfix)
    for i in range(length):
        if isOperator(postfix[i]):
            op1=stack[-1]
            stack.pop()
            op2=stack[-1]
            stack.pop()
            temp=postfix[i]+op2+op1
            stack.append(temp)
            
        else:
            stack.append(postfix[i])
    ans=""
    for i in stack:
        ans+=i
    return ans            

isOperator(postfix)
res=postfix_to_prefix(postfix)
print(res)

# %%
prefix=input("enter an expression")
def prefix_to_infix(prefix):
    stack=[]
    i=len(prefix)-1
    while i>=0:
        if not isOperator(prefix[i]):
            stack.append(prefix[i])
            i-=1
            
        else:
            str="("+stack.pop()+prefix[i] +stack.pop()+")"
            stack.append(str)
            i-=1
    return stack.pop()

def isOperator(c):
    if c=="+" or c=="*" or c=="-" or c =="/" or c == "^" or c=="(" or c == ")"  :
        return c
    else:
        pass 
    
res=prefix_to_infix(prefix)
print(res)
isOperator(prefix)

# %%
num=int(input("enter value"))
def TowerOfHanoi(n,from_rod,to_rod,aux_rod):
    if n==0:
        return 
    TowerOfHanoi(n-1,from_rod,aux_rod,to_rod)
    print("Move disk",n,"from rod",from_rod,"to rod",to_rod)
    TowerOfHanoi(n-1,aux_rod,to_rod,from_rod)
TowerOfHanoi(num,'A','C','B')

# %%
class Stack:

    def __init__(self):
        self.Elements = []
          
    
    def push(self, value):
        self.Elements.append(value)
        
    
    def pop(self):
        return self.Elements.pop()
      
    
    def empty(self):
        return self.Elements == []
      
    
    def show(self):
        for value in reversed(self.Elements):
            print(value)
def BottomInsert(s, value):

    if s.empty(): 
          
        
        s.push(value)
          
    
    else:
        popped = s.pop()
        BottomInsert(s, value)
        s.push(popped)
  

def Reverse(s):
    if s.empty():
        pass
    else:
        popped = s.pop()
        Reverse(s)
        BottomInsert(s, popped)
  
  

stk = Stack()
  
stk.push(1)
stk.push(2)
stk.push(3)
stk.push(4)
stk.push(5)
  
print("Original Stack")
stk.show()
  
print("\nStack after Reversing")
Reverse(stk)
stk.show()
